# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv(r"E:\notes\Geo Data - Countries, RegionsStates, Cities (1).csv")

# %%
data.columns
# Out:
# Index(['id', 'city', 'longitude', 'latitude'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1700 non-null   int64
#  1   city       1700 non-null   object
#  2   longitude  1700 non-null   float64
#  3   latitude   1700 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 53.3+ KB

# %%
data.ndim
# Out:
# 2

# %%
data.head
# Out:
# <bound method NDFrame.head of            id      city  longitude   latitude
# 0     1103162     Achad  72.883333  20.216667
# 1     1103190    Adalaj  72.583333  23.166667
# 2     1103212    Adesar  70.983333  23.550000
# 3     1103218     Adhoi  70.516667  23.400000
# 4     1103229  Adityana  69.682500  21.715556
# ...       ...       ...        ...        ...
# 1695  1135104     Wondh  70.400000  23.300000
# 1696  1135113  Wumlasir  72.683333  21.500000
# 1697  1135324  Zainabad  71.766667  23.283333
# 1698  1103490     Ákria  71.450000  22.100000
# 1699  1114910      Ïdar  73.000000  23.833333
#
# [1700 rows x 4 columns]>

# %%
print(len(data.city.unique()))
print(data.city.unique())
# Out:
# 1700
# ['Achad' 'Adalaj' 'Adesar' ... 'Zainabad' 'Ákria' 'Ïdar']

# %%
#distibution of cities
sns.displot(data['city'],bins=10)

# %%
sns.boxplot(data['city'])
# Out:
# <Axes: xlabel='city', ylabel='Count'>

# %%
import plotly.express as px
fig = px.sunburst(data, path=['city','longitude','latitude'], title="Cities", width=500, height=500, color_continuous_scale='RdBu')
fig.show()

# %%
df = pd.read_csv(r"E:\notes\friedman-test-data.csv")
df.head()
# Out:
#    week1  week4  week8
# 0      1      1      1
# 1      2      2      2
# 2      2      2      3
# 3      2      3      2
# 4      3      1      2

# %%
coreelation = df.corr()
coreelation
# Out:
#           week1     week4     week8
# week1  1.000000  0.162405  0.518087
# week4  0.162405  1.000000  0.172123
# week8  0.518087  0.172123  1.000000

# %%
sns.heatmap(coreelation)
# Out:
# <Axes: >
